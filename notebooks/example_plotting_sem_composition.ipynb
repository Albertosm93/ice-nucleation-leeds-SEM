# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import matplotlib
import pandas as pd
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

os.chdir("..") #go to main folder of repository

#importing custom functions
from src.functions_sem import plot_SEM_composition #import function to plot chemical SEM data
from src.functions_classification import (
    classification_alaska,
    classification_barbados,
    classification_iceland,
    classification_standard
) #import function to classify SEM particles
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
###inputs### first define path and settings

#path to the csv file with the particles
path=r'C:\Users\py15asm\Documents\GitHub\ice-nucleation-leeds-SEM\data\chemical_processed\examples\\171002_1624_1640_432L_OP_UP_chemical_processed.csv'
#path=r'C:\Users\py15asm\Documents\GitHub\ice-nucleation-leeds-SEM\data\\chemical_processed\180316_FAAM_2045_2126_0.51V_chem_processed.csv'

#number of bins for high magnification analysis
nbins_submicron=3 

#number of bins for low magnification analysis
nbins_supermicron=7

#lower limit of the high magnification analysis
lower_lim=0.3 #in um

#upper limit of the analysis
upper_lim=10 #in um

#lower limit of the low magnification analysis
mag_threshold=0.8

#position of the number of particles in each bin
count_position=0.5

#fontsize
fontsize=12

#hatches and hatches style
hatches=True
hatches_style=1 # could be 1 or 2

#legend
legend_plot=True

#choose a classification scheme from the schemes imported from functions_classification 
classification_function=classification_standard



### Plot ###

# define plot size 
plt.figure(figsize=(6,3),dpi=300)

#run function 
finaldata=plot_SEM_composition(path,nbins_submicron,nbins_supermicron,lower_lim,upper_lim,mag_threshold,count_position,fontsize,hatches,hatches_style,classification_function,legend_plot)  

plt.savefig("outputs/examples/171002_1624_1640_432L_OP_UP_chemical.png",doi=150,bbox_inches="tight")
# Out:
# N = 5830.0

# %%
#Second example, small layout

#number of bins for high magnification analysis
nbins_submicron=3 

#number of bins for low magnification analysis
nbins_supermicron=7

#lower limit of the high magnification analysis
lower_lim=0.3 #in um

#upper limit of the analysis
upper_lim=10 #in um

#lower limit of the low magnification analysis
mag_threshold=0.8

#position of the number of particles in each bin
count_position=0.5

#fontsize
fontsize=6

#hatches and hatches style
hatches=True
hatches_style=2 # could be 1 or 2

#legend
legend_plot=False

#choose a classification scheme from the schemes imported from functions_classification 
classification_function=classification_standard



### Plot ###

# define plot size 
plt.figure(figsize=(3,1.5),dpi=300)

#run function 
finaldata=plot_SEM_composition(path,nbins_submicron,nbins_supermicron,lower_lim,upper_lim,mag_threshold,count_position,fontsize,hatches,hatches_style,classification_function,legend_plot)  

plt.savefig("outputs/examples/171002_1624_1640_432L_OP_UP_chemical_small_layout.png",doi=150,bbox_inches="tight")
# Out:
# N = 5830.0
